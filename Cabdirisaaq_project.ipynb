# %% [markdown]
# <h1 style='text-align: center;'>  Learning Opportunity 02 </h1>
# <h4 style='text-align: center;'> Full name: Abdirisaaq Abdilaahi Abdi Maygaag                                                     </h4>
# <h4 style='text-align: center;'> Student ID:     2432398                                                </h4>

# %% [markdown]
# ## Exercise 1:
# Write a program that asks the user to enter an integer. The program should display “Positive” if the number is greater than 0, “Negative” if the number is less than 0, and “Zero” if the number is equal to 0. The program should then display “Even” if the number is even, and “Odd” if the number is odd.
#
# For example:
# - if the number is 6, the program should display " even positive"
# - if the number is 5, the program should display "odd positive"
# - if the number is -6, the program should display "even negative"
# - if the number is -5, the program should display "odd negative"
# - if the number is 0, the program should display "even zero"

# %%
# Answer
def kalasaare():
    number=int(input("soo geli number wll"))
    if number>0:
        if number%2==0:
            print("even positive")
        if number%2==1:
            print("odd positve")
    if number<0:
         if number%2==0:
           print("even negative")
         if number%2==1:
            print("odd negative")
    if number==0:
        print("Zero😂")
        
kalasaare()
# Out:
# odd negative

# %% [markdown]
# ## Exercise 2:
# The area of a rectangle is the rectangle’s length times its width. Write a program that asks or the length and width of two rectangles. The program should tell the user which rectangle has the greater area, or if the areas are the same.

# %%
# Answer
def bed_isbarbardhige():
    rect1=input("soo geli dherer iyo balaca ',' u dhaxaysii")
    rect1=rect1.split(",")
    h1=float(rect1[0])
    w1=float(rect1[1])


    rect2=input("soo geli dherer iyo balaca ',' u dhaxaysii markan shayga labaad")
    rect2=rect2.split(",")
    h2=float(rect2[0])
    w2=float(rect2[1])    
    
    area1=h1*w1
    area2=h2*w2

    if area1>area2:
        print(f"bedka koowaad oo ah {area1} ayaa ka wayn {area2}")
    elif area2>area1:
        print(f"bedka labaad oo ah {area2} ayaa ka wayn {area1}")
    else :
        print("wooow way is leeg yihiin .... dilaal miyaad ahayd?")


bed_isbarbardhige()
# Out:
# bedka koowaad oo ah 400.0 ayaa ka wayn 300.0

# %% [markdown]
# ## Exercise 3:
# Write a program that asks the user for a month as a number between 1 and 12. The program should display a message indicating whether the month is in the first quarter, the second quarter, the third quarter, or the fourth quarter of the year. Following are the guidelines:
#
# - If the user enters either 1, 2, or 3, the month is in the first quarter.
# - If the user enters a number between 4 and 6, the month is in the second quarter.
# - If the number is either 7, 8, or 9, the month is in the third quarter.
# - If the month is between 10 and 12, the month is in the fourth quarter.
# - If the number is not between 1 and 12, the program should display an error.

# %%
# Answer
def xiliyo():
    month=int(input("soo geli bisha 1-12"))
    if month<4:
        print("first quarter")
    elif month>=4 and month<7:
        print("second quarter")
    elif month>=7 and month<10:
        print("third quarter")
    elif month>=10 and month<13:
        print("fourth quarter")
    else:
        print("wax caadiya soo geli 1 ilaa 12 weeyi bilaha sanadku")
        
xiliyo()
# Out:
# wax caadiya soo geli 1 ilaa 12 weeyi biluhu

# %% [markdown]
# ## Exercise 4:
# Write a program that prompts the user to enter a number within the range of 1 through 10. The program should display the Roman numeral version of that number. If the number is outside the range of 1 through 10, the program should display an error message. The following table shows the Roman numerals for the numbers 1 through 10:
# - 1 >> I
# - 2 >> II
# - 3 >> III
# - 4 >> IV
# - 5 >> V
# - 6 >> VI
# - 7 >> VII
# - 8 >> VIII
# - 9 >> IX
# - 10 >> X

# %%
# Answer
def romaneeye():
    n=int(input("soo geli number si aan kuugu sheego romankiisa"))
    if n==1:
        print("I")
    if n== 2:
       print("II")
    if n==3:
        print("III")
    if n== 4:
       print("IV")
    if n==5:
        print("V")
    if n== 6:
       print("VI")
    if n==7:
        print("VII")
    if n== 8:
       print("VIII")
    if n== 9:
       print("IX")
    if n== 10:
       print("X")
    if n>10:
       print("weli maynaan gaaadhin😂")
    
romaneeye()
# Out:
# VI

# %% [markdown]
# ## Exercise 5:
# Scientists measure an object’s mass in kilograms and its weight in newtons. If you know the amount of mass of an object in kilograms, you can calculate its weight in newtons with the following formula:
# > weight = mass * 9.8
#
# Write a program that asks the user to enter an object’s mass, then calculates its weight. If the object weighs more than 500 newtons, display a message indicating that it is too heavy. If the object weighs less than 100 newtons, display a message indicating that it is too light.

# %%
# Answer
def culays():
    mass=int(input("soo geli cufsjiidka"))
    weight=mass*9.8
    if weight>500:
        print(f"waa culays {weight}")
    if weight<100:
        print(f"waa fudayd {weight}")
    if weight>100 and weight<500:
        print(weight)
culays()
# Out:
# waa culays 980.0000000000001

# %% [markdown]
# ## Exercise 6:
# Magic Dates
#
# The date June 10, 1960, is special because when it is written in the following format, the month times the day equals the year:
#
# > 6/10/60
#
# Design a program that asks the user to enter a month (in numeric form), a day, and a two digit year. The program should then determine whether the month times the day equals the year. If so, it should display a message saying the date is magic. Otherwise, it should display a message saying the date is not magic.

# %%
# Answer
date=input("soo geli date ka aad dhalatay, uqor sidan:05/18/91 for 18 may")
dates=date.split("/")
if int(dates[0])*int(dates[1])==int(dates[2]):
    print(f'wow magic date {date}')

else:
    print("not that magic😞")
# Out:
# wow magic date 6/10/60

# %% [markdown]
# ## Exercise 7:
# A class has two tests worth 25 points each along with a main exam worth 50 points. For a student to pass the class, they must obtain an overall score of at least 50 points, and must obtain at least 25 points in the main exam. If a student’s total score is less than 50 or they obtain less than 25 points in the main exam, they receive a grade of “Fail”. Otherwise, their grade is as follows:
#  - If they get more than 80, they get a grade of “Distinction”. 50–59 = “Pass”
#  - If they get less than 80 but more than 60, they get a “Credit” grade.
#  - If they get less than 60, they get a ”Pass” grade.
#
# Write a program that prompts the user to enter their points for both tests and the exam and converts the values to integers. The program should first check if the points entered for the tests and exam are valid. If any of the test scores are not between 0 and 25, or the exam score is not between 0 and 50, the program should display an error message. Otherwise, the program should display the total points and the grade.

# %%
# Answer
def exams():
    mid1=int(input("soo geli mid1"))
    mid2=int(input("soo geli mid2"))
    main=int(input("soo geli main exam"))
    if(mid1>25 or mid2>25 or main>50):
        print("ku noqo")
        return
    total=main+mid1+mid2
    if main>=25 and total>=50:
        if total>=80:
            print(f"that guy is distinction ,{total}")
        if total>=60 and total<80:
            print(f"that guy have credit grade,{total}")
        if total >=50 and total<60:
            print(f"that guy constitutionally passed, he got {total}")

    else:
        print(f"that student failed,he only got {total}")
    
exams()
# Out:
# that student failed,he only got 46

# %% [markdown]
# ## Exercise 8:
# Ask for two numbers. If the first one is larger than the second, display the second number first and then the first number, otherwise show the first number first and then the second

# %%
# Answer
twonumbers=input("enter two numbers separated with coma")
twonumbers=twonumbers.split(",")
twonumbers=[int(n) for n in twonumbers]
twonumbers.sort()
print(f"their orders are {twonumbers}")
# Out:
# their orders are [13, 80]

# %% [markdown]
# ## Exercise 9:
# Ask the user to enter a number that is under 20. If they enter a number that is 20 or more, display the message "Too high", otherwise display "Thank you".

# %%
# Answer
def u20():
    n=int(input("soo geli number kayar 20"))
    if n<20:
        print("thanks")
    if n>=20:
        print("Too higgh")
u20()
# Out:
# thanks

# %% [markdown]
# ## Exercise 10:
# Ask the user to enter a number between 10 and 20 (inclusive. If they enter a number with this range, display the message "Thank you", otherwise display the message "incorrect answer".

# %%
# Answer
def btw10t20():
    n=int(input("soo geli number u dhexeeya 10 ilaa 20"))
    if n>=10 and n<=20:
        print("thanks")
    else:
        print("incorrect answer")
btw10t20()
# Out:
# incorrect answer

# %% [markdown]
# ## Exercise 11:
# Ask the user to enter their favourite color. If they enter red (consider the different writting of red: red, Red, RED,...), display the message " I like red too", otherwise display the message "I do not like [color], I like red"

# %%
# Answer
color=input("enter your favoirate color")
if color=="red" or color=="RED" or color=="Red":
    print("I like red too!")
else:
    print(f"ma jecli {color}-gaa , anuu 'red' ayaan jeclahay")
# Out:
# I like red too!

# %% [markdown]
# ## Exercise 12:
# Ask the user to enter 1, 2 or 3. If they enter 1, display the message "Thank you", if the enter 2, display the message 'Well done', if they enter 3, display the message "Correct". If they enter anything else, display "Error message"

# %%
# Answer
kowlabasadex=input("soo geli 1 ama 2 ama 3")
if kowlabasadex=="1":
    print("Thank you")
elif kowlabasadex=="2":
    print("well done")
elif kowlabasadex=="3":
    print("correct")
else:
    print("khalad, amarka qaado walaal:'soogeli 1 ama 2 ama 3 '")
# Out:
# well done

# %% [markdown]
# ## Exercise 13:
#  Write a Python program to check if the given string is a palindrome.
#  A palindrome number is a number that remains the same when its digits are reversed. This means the number reads the same forwards and backward. For example, 121, 1331, and 4554 are all palindrome numbers.

# %%
# Answer
def palindrome_checker():
    number=input("soo geli number")
    number_rev=number[::-1]
    if number==number_rev:
        print(f"{number} waa palindrome")
    else:
        print(f'{number} maaha palindrome, rogaalkiisu waa {number_rev}')
palindrome_checker()
# Out:
# 121 waa palindrome

# %% [markdown]
# ## Exercise 14:
# Write a Python program to count the number of even and odd numbers from a list.

# %%
# Answer
def even_odd(ns):
    even=[]
    odd=[]
    for n in ns:
        if n%2==0:
            even.append(n)
        else:
            odd.append(n)
    
    print(f"evens are {even} and odds are {odd}")
even_odd([3,4,5,6,3,2,5,89])
# Out:
# evens are [4, 6, 2] and odds are [3, 5, 3, 5, 89]

# %% [markdown]
# ## Exercise 15:
# Given a positive integer number, use a for loop to find the sum of its digits.
# for example:
# - if the number is 61, the sum is 6+1=7
# - if the number is 1815, the sum is 1+8+1+5=15
# - if the number is 9, the sum is 9

# %%
# Answer
numbers=input("soo geli number,waxaan kuu sheegi isugaynta godadkiisa")
numbers_list=[int(numberkii) for numberkii in numbers]
print(f"isugayntoodu waa {sum(numbers_list)}")
# Out:
# isugayntoodu waa 3

# %% [markdown]
# ## Exercise 16:
# Write a Python program to calculate the sum of all the odd numbers within the given range.
# For example:
# - range(4), the out should be 0+1+2+3=6

# %%
# Answer
def odd_summer(rangeka):
    total=0
    for i in range(rangeka):
        if i%2==1:
            total+=i
    print(f"{range(rangeka)} kinsigiisa isugayntiisu waa {total}")
odd_summer(10)
# Out:
# range(0, 10) kinsigiisa isugayntiisu waa 25

# %% [markdown]
# ## Exercise 17:
# Write a program that asks the user to guess a secret number . Keep prompting until the user guesses it correctly.

# %%
# Answer
import numpy
rnumber=numpy.random.randint(0,10)
def guessf():
    guess=int(input("garo, soo geli hal number"))
    while(guess!=rnumber):
        guess=int(input("garo, soo geli hal number"))
    print(f"waad saxday wuxuu ahaa {guess} 😂")
guessf()
# Out:
# waad saxday 1

# %% [markdown]
# ## Exercise 18:
# Use a while loop to calculate the sum of all even numbers from 1 to 100.

# %%
# Answer
n=1
sm=0
while(n<100):
  sm+=n
  n+=1
print(sm)
# Out:
# 4950

# %% [markdown]
# ## Exercise 19:
# Given an integer, use a while loop to reverse its digits. For example, given 1234, the output should be 4321.

# %%
# Answer
def reverse(numberkan):
    numberkan=str(numberkan)
    reversed_number=""
    k=0
    i=len(numberkan)
    while(i>k):
        reversed_number+=numberkan[i-k-1]
        k+=1
    print(reversed_number)
reverse(123)
# Out:
# 321

# %% [markdown]
# ## Exercise 20:
# Write a Python program to find those numbers which are divisible by 7 and multiples of 5, between 1500 and 2700 (both included).

# %%
# Answer
divisiblesof7_multiplesof5=[]
for number in range(1500,2701,1):
    if (str(number).endswith("0") or str(number).endswith("5")) and number%7==0 :
        divisiblesof7_multiplesof5.append(number)
print(divisiblesof7_multiplesof5)
# Out:
# [1505, 1540, 1575, 1610, 1645, 1680, 1715, 1750, 1785, 1820, 1855, 1890, 1925, 1960, 1995, 2030, 2065, 2100, 2135, 2170, 2205, 2240, 2275, 2310, 2345, 2380, 2415, 2450, 2485, 2520, 2555, 2590, 2625, 2660, 2695]

# %% [markdown]
# ## Exercise 21:
# Write a function calculation() that accepts two parameters and calculates both addition and subtraction. The function must return both results in a single return statement.

# %%
# Answer
def calcultaion(num1,num2):
    sumkoodu=num1+num2
    diff=num1-num2
    return (sumkoodu,diff)
calcultaion(10,5)
# Out:
# (15, 5)

# %% [markdown]
# ## Exercise 22
# Write a Python function that takes a number as a parameter and checks whether the number is prime or not.
#
# Note : A prime number (or a prime) is a natural number greater than 1 and that has no positive divisors other than 1 and itself.

# %%
# Answer
import math
def is_prime(number):
    if number<1:
        return False
    root=int(math.sqrt(number))+1
    ku_eeg=range(2,root)
    for i in ku_eeg:
        if number%i==0:
            return False
    return True
print(is_prime(157))
# Out:
# True

# %% [markdown]
# ## Exercise 23
# Write a function named num_test that takes a number as input. If the number is greater than 10, the function should return “Greater than 10.” If the number is less than 10, the function should return “Less than 10.” If the number is equal to 10, the function should return “Equal to 10.”

# %%
# Answer
def num_test(n):
    if n>10:
        print("greater than 10")
    elif n<10:
        print("less than 10")
    else:
        print("it is equal to 10")
num_test(12)
# Out:
# greater than 10

# %% [markdown]
# ## Exercise 24
# Write a function that will return the number of digits in an integer.

# %%
# Answer
def digiter(number):
    return len(str(number))
digiter(345)
# Out:
# 3

# %% [markdown]
# ## Exercise 25
# Write a function that reverses its string argument.

# %%
# Answer
def reverser(strr):
    return strr[::-1]

reverser("asc")
# Out:
# 'csa'

# %% [markdown]
# ## Exercise 26
# Write a function sum_of_squares(xs) that computes the sum of the squares of the numbers in the list xs. For example, sum_of_squares([2, 3, 4]) should return 4+9+16 which is 29:

# %%
# Answer
def sum_of_squares(xs):
    total=0
    for x in xs:
        total+=x**2
    return total
sum_of_squares([2,3,4])
# Out:
# 29

# %% [markdown]
# ## Exercise 27
# Write a function called is_even(n) that takes an integer as an argument and returns True if the argument is an even number and False if it is odd.

# %%
# Answer
def is_even(n):
    if n%2==0:
        return True
    else:
        return False
is_even(13)
# Out:
# False
